# %% [markdown]
# # Tensorboard
#
# Another perk of using the TensorFlow backend is that it comes with TensorBoard. It's a built-in graphical layout for analyzing models. It's not uncommon to run this as a separate server where you can access the board through a webpage. However, it also can seamlessly integrate with our notebooks (and this requires a bit less configuration).

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-8605761316ca6856" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8605761316ca6856");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
